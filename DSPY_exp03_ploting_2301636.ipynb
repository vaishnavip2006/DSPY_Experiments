# %% [markdown]
# #Experiment No : 03
#
# ##**Aim :**
# Learn basics of maplotlib library and its use as visualisation tool in data science pipeline and learn about line plots and scatter plots.

# %% [markdown]
# ## **Theory :**
#
# **Matplotlib** is a multi-platform data visualization library built on NumPy arrays, and designed to work with the broader SciPy stack.
#
# It was conceived by John Hunter in 2002, originally as a patch to IPython for enabling interactive MATLAB-style plotting via gnuplot from the IPython command line.
#
# One of Matplotlib’s most important features is its ability to play well with many operating systems and graphics backends.
# Matplotlib supports dozens of backends and output types, which means you can count on it to work regardless of which operating system you are using or which output format you wish.
#
# This cross-platform, everything-to-everyone approach has been one of the great strengths of Matplotlib. It has led to a large user base, which in turn has led to an active developer base and Matplotlib’s powerful tools and ubiquity within the scientific Python world.
#
# In recent years, however, the interface and style of Matplotlib have begun to show their age. Newer tools like ggplot and ggvis in the R language, along with web visualization toolkits based on D3js and HTML5 canvas, often make Matplotlib feel clunky and old-fashioned.

# %% [markdown]
# ## Performance :
#
# [Students need to execute eaxh and every cell in this section and note the output of the same. Once done they have to answer Questions mentioned in review section]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.__version__
# Out:
# '3.10.0'

# %%
#setting ploting style
plt.style.use('classic')

# %%
# %matplotlib inline
import numpy as np
x = np.linspace(0, 10, 1000)

fig = plt.figure()
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# ### Saving Figures to File
#
# One nice feature of Matplotlib is the ability to save figures in a wide variety of formats.
# Saving a figure can be done using the ``savefig()`` command.
# For example, to save the previous figure as a PNG file, you can run this:

# %%
#Save above plot with file named my_figure.png in Current Working Directory
fig.savefig('my_figure.png')

# %%
# Cross check the folder content
# !ls -lh my_figure.png
# Out:
# -rw-r--r-- 1 root root 45K Mar 19 11:58 my_figure.png

# %%
# use Image package in python to check contents of png file in cwd
from IPython.display import Image
Image('my_figure.png')

# %%
#checking supported file types by matplotlib
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# ### Matplotlib API Interfaces
#
# A potentially confusing feature of Matplotlib is its dual interfaces: a convenient MATLAB-style state-based interface, and a more powerful object-oriented interface. This section we will review them breifly.
#
# #### MATLAB-style Interface
#
# Matplotlib was originally written as a Python alternative for MATLAB users, and much of its syntax reflects that fact.
# The MATLAB-style tools are contained in the pyplot (``plt``) interface. See the example inthe code cell below.

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# This interface is *stateful*: It keeps track of the "current" figure and axes, which are where all ``plt`` commands are applied.
#
# You can get a reference to these using the ``plt.gcf()`` (get current figure) and ``plt.gca()`` (get current axes) routines.
#
# While this stateful interface is fast and convenient for simple plots, it is easy to run into problems.
#
# For example, once the second panel is created, how can we go back and add something to the first? This interface does have a solution but it is not a easy solution.

# %% [markdown]
# #### Object-oriented interface of Matplotlib
#
# The object-oriented interface can nicely handle more complicated  plots, and for when you want more control over your figure.
#
# Rather than depending on some notion of an "active" figure or axes, in the object-oriented interface the plotting functions are *methods* of explicit ``Figure`` and ``Axes`` objects.
#
# To re-create the previous plot using this style of plotting, you might do the following:

# %%
#First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
#  The difference is as small as switching ``plt.plot()`` to ``ax.plot()``.
#
#  Now we start exploring different types of plots in following sections.

# %% [markdown]
# ### Simple Line Plots
#
# Perhaps the simplest of all plots is the visualization of a single function ``y = f(x)``.
#
# Here we will take a first look at creating a simple plot of this type.

# %%
# Import all necesssary libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
#ploting style chosen is that of seaborn-whitegrid
plt.style.use('classic')

# %%
# creating objects of figure and axes.
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# In Matplotlib, the *figure* (an instance of the class ``plt.Figure``) can be thought of as a single container that contains all the objects representing axes, graphics, text, and labels.
#
# The *axes* (an instance of the class ``plt.Axes``) is what we see above: a bounding box with ticks and labels, which will eventually contain the plot elements that make up our visualization.
#
# Once we have created an axes, we can use the ``ax.plot`` function to plot some data.

# %%
# we will plot sine curve using ax.plot function
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %% [markdown]
# The word line in line plot refers to the function we want to plot. Multiple functions can be plot on same plot like shown below.

# %%
plt.plot(x, np.sin(x))   #shown in blue
plt.plot(x, np.sin(2*x)) #Shown in green
plt.plot(x,(x**(1/2))/2) #Shown in red

# %% [markdown]
# ###Adjusting the Plot: Line Colors and Styles
#
# The first adjustment you might wish to make to a plot is to control the line colors and styles. The *plt.plot()* function takes additional arguments that can be used to specify these. To adjust the color, you can use the color keyword, which accepts a *string* argument representing virtually any imaginable color. The color can be specified in a variety of ways:

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# ###Adjusting the Plot: Axes Limits
#
# Matplotlib does a decent job of choosing default axes limits for your plot, but sometimes it's nice to have finer control. The most basic way to adjust axis limits is to use the *plt.xlim()* and *plt.ylim()* methods:

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %%
# Reverse the Axis Limit
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %% [markdown]
# A useful related method is plt.axis() (note here the potential confusion between axes with an e, and axis with an i). The plt.axis() method allows you to set the x and y limits with a single call, by passing a list which specifies **[xmin, xmax, ymin, ymax] :**

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %% [markdown]
# ###Labeling Plots
#
# As the last piece of this section, we'll briefly look at the labeling of plots: titles, axis labels, and simple legends.
#
# Titles and axis labels are the simplest such labels—there are methods that can be used to quickly set them:

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# When multiple lines are being shown within a single axes, it can be useful to create a plot legend that labels each line type.
#
# Again, Matplotlib has a built-in way of quickly creating such a legend. It is done via the (you guessed it) **plt.legend()** method.
#
# Though there are several valid ways of using this, I find it easiest to specify the label of each line using the label keyword of the plot function:

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %% [markdown]
# In the object-oriented interface to plotting, rather than calling these functions individually, it is often more convenient to use the ax.set() method to set all these properties at once:

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');

# %% [markdown]
# ###Simple Scatter Plots
# Another commonly used plot type is the simple scatter plot, a close cousin of the line plot. Instead of points being joined by line segments, here the points are represented individually with a dot, circle, or other shape.

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %% [markdown]
# ###Scatter Plots with plt.scatter
#
# A second, more powerful method of creating scatter plots is the plt.scatter function, which can be used very similarly to the plt.plot function:

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
plt.scatter(x, y, marker='o');

# %%
# Consider this code for scatter plot

rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale

# %% [markdown]
# ##Question Answer Section
#
#
# **1. List any 2 Python APIs that are used for *Plotting Graphs*.**
#
#
# Here are two Python APIs for plotting graphs with a bit more theory:
#
# 1. **Matplotlib**
#    Matplotlib is a foundational plotting library in Python that provides a low-level interface for creating a wide variety of static, animated, and interactive graphs. It follows a structure similar to MATLAB, making it familiar for many users. The core module, *pyplot*, allows step-by-step graph creation, while the object-oriented interface offers more control over figures and axes. It supports multiple output formats (PNG, PDF, SVG) and is highly customizable, making it suitable for both simple and complex visualizations.
#
# 2. **Seaborn**
#    Seaborn is a high-level data visualization library built on top of Matplotlib. It is designed specifically for statistical data visualization and works well with data structures like Pandas DataFrames. Seaborn simplifies complex plotting tasks by providing built-in themes and color palettes, improving the overall aesthetics of graphs. It includes advanced visualizations such as heatmaps, pair plots, violin plots, and regression plots, making it especially useful for data analysis and exploration.
#
#
# **2. Name 2 important mechanisms used for accessing Matplotlib API.**
#
#
# Two important mechanisms used for accessing the Matplotlib API are:
#
# 1. **Pyplot Interface (State-based interface)**
#    This is the most commonly used way to access Matplotlib. It uses the `pyplot` module (usually imported as `plt`) and works in a state-machine style, where commands automatically apply to the current figure and axes. It is simple and convenient for quick plotting and beginners.
#
# 2. **Object-Oriented Interface**
#    This approach gives more control by explicitly creating and managing figure and axes objects. Instead of relying on global state, you work with objects like `Figure` and `Axes`. It is more flexible and recommended for complex and customized plots.
#
#
#
# **3. Create a collection of 100 random normal numbers with parameter mean 30, sd 4 and store it in object `summer_temp`.**
#
#
#
# You can create a collection of 100 random numbers from a normal distribution (mean = 30, standard deviation = 4) using NumPy as follows:
#
# ```python
# import numpy as np
#
# summer_temp = np.random.normal(loc=30, scale=4, size=100)
# ```
#
# **Explanation:**
#
# * `loc=30` sets the mean
# * `scale=4` sets the standard deviation
# * `size=100` generates 100 random values
#
# The variable `summer_temp` will store the generated data.
#
#
#
# **4. Sort the above set and store it in object `sorted_summer_temp`.**
#
# You already have a NumPy array `summer_temp` containing 100 random numbers from a normal distribution. Now, you want to sort them. There are two main ways to do this in NumPy:
#
# ---
#
# ### **1. Using `np.sort()` (creates a new sorted array)**
#
# ```python
# sorted_summer_temp = np.sort(summer_temp)
# ```
#
# * **What it does:**
#
#   * `np.sort(summer_temp)` **returns a new array** where all elements are in ascending order.
#   * The original array `summer_temp` **remains unchanged**.
#
# * **Why use it:**
#
#   * Safe if you want to keep the original data for further analysis or comparison.
#   * Produces a sorted copy quickly and efficiently.
#
# * **Example:**
#
#   ```python
#   summer_temp = [32.1, 28.5, 30.7]
#   sorted_summer_temp = np.sort(summer_temp)
#   print(sorted_summer_temp)  # Output: [28.5, 30.7, 32.1]
#   print(summer_temp)         # Output: [32.1, 28.5, 30.7] (unchanged)
#   ```
#
# ---
#
# ### **2. Using `.sort()` method (sorts in-place)**
#
# ```python
# summer_temp.sort()
# ```
#
# * **What it does:**
#
#   * The original array `summer_temp` is **modified** and arranged in ascending order.
#   * No new array is created.
#
# * **Why use it:**
#
#   * Saves memory if you don’t need the original order of data.
#   * Slightly faster because it doesn’t create a copy.
#
# * **Example:**
#
#   ```python
#   summer_temp = [32.1, 28.5, 30.7]
#   summer_temp.sort()
#   print(summer_temp)  # Output: [28.5, 30.7, 32.1] (original array is changed)
#   ```
#
# ---
#
#
# **5. Store average of 25 consecutive elements from `sorted_summer_temp` into object `x` and plot it as a *line plot*. What kind of information do you get about the data?**
#
#
#  **step by step**. We’ll take the `sorted_summer_temp` array, calculate averages of 25 consecutive elements, store them in `x`, and then plot a line graph.
#
# ---
#
# ### **Step 1: Calculate averages of 25 consecutive elements**
#
# Since `sorted_summer_temp` has 100 elements, dividing into groups of 25 gives 4 groups. We can use NumPy’s `reshape` and `mean`:
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Assuming sorted_summer_temp already exists
# x = sorted_summer_temp.reshape(4, 25).mean(axis=1)
# print(x)
# ```
#
# **Explanation:**
#
# * `.reshape(4, 25)` → splits 100 numbers into 4 rows of 25 elements each.
# * `.mean(axis=1)` → computes the mean of each row (group of 25 numbers).
# * `x` now contains 4 average values.
#
# ---
#
# ### **Step 2: Plot as a line graph**
#
# ```python
# plt.plot(x, marker='o')
# plt.title("Average of 25 Consecutive Temperatures")
# plt.xlabel("Group Number")
# plt.ylabel("Average Temperature")
# plt.grid(True)
# plt.show()
# ```
#
# **Explanation:**
#
# * `marker='o'` → shows each average as a point on the line.
# * X-axis → group number (1 to 4)
# * Y-axis → average temperature of each group
#
# ---
#
# ### **Step 3: What information this gives**
#
# 1. **Trend of the data:**
#
#    * Since the array is sorted, the line plot will **show an increasing trend**, going from the lowest 25 temperatures to the highest 25.
#
# 2. **Grouped behavior:**
#
#    * Each point represents the **average of 25 consecutive elements**, giving a smoother view of the temperature distribution.
#
# 3. **Data distribution insight:**
#
#    * The differences between consecutive points show how the data spreads.
#    * If the line is almost straight, the data is **uniformly distributed**; if it curves sharply, the data is **skewed** or unevenly distributed.
#
# ---
#
# **6. Repeat the above step for `summer_temp`, store summary in object `y` and this time use a *scatter plot* to plot values. What kind of information do you get about the data?**
#
#
#
#  instead of using the **sorted array**, we’ll use the original `summer_temp` array, calculate averages of 25 consecutive elements, and plot a **scatter plot**. Let’s go step by step.
#
# ---
#
# ### **Step 1: Calculate averages of 25 consecutive elements from `summer_temp`**
#
# ```python id="d9x6rq"
# y = summer_temp.reshape(4, 25).mean(axis=1)
# print(y)
# ```
#
# **Explanation:**
#
# * `summer_temp.reshape(4, 25)` splits the 100 random numbers into 4 groups of 25 elements **in the original (unsorted) order**.
# * `.mean(axis=1)` calculates the average of each group.
# * `y` now contains 4 average values for the unsorted data.
#
# ---
#
# ### **Step 2: Plot the averages using a scatter plot**
#
# ```python id="k9q28t"
# plt.scatter(range(1, 5), y, color='red', s=50)
# plt.title("Average of 25 Consecutive Temperatures (Original Data)")
# plt.xlabel("Group Number")
# plt.ylabel("Average Temperature")
# plt.grid(True)
# plt.show()
# ```
#
# **Explanation:**
#
# * `range(1,5)` → X-axis: group numbers 1 to 4
# * `y` → Y-axis: average temperature of each group
# * `color='red'` → makes the points visible
# * `s=50` → size of each scatter point
#
# ---
#
# ### **Step 3: What information this gives**
#
# 1. **Shows variability in the original data order:**
#
#    * Because `summer_temp` is **unsorted**, the points may **jump up or down**, reflecting the randomness in the data.
#
# 2. **Grouped trend is less smooth:**
#
#    * Unlike the sorted version, the scatter plot may not show a clear increasing trend.
#    * This helps you **see the natural fluctuations** in the dataset.
#
# 3. **Randomness insight:**
#
#    * Any sharp differences between consecutive points indicate **local variation** in the temperature data.
#
# ---
#
# ✅ **Key Comparison:**
#
# * Line plot of `sorted_summer_temp` → smooth trend, shows **overall distribution**.
# * Scatter plot of `summer_temp` → irregular trend, shows **randomness and local variation**.
#
# ---
#
#
#
# **7. Plot `summer_temp` and `y` together in the same line plot.**
#
#
#
#
#  We can plot the **original 100 random temperatures (`summer_temp`)** and the **averages of 25 consecutive elements (`y`)** together in a single line plot to compare the raw data with the grouped averages. Here's how:
#
# ---
#
# ### **Step 1: Prepare the data**
#
# * `summer_temp` → 100 individual points
# * `y` → 4 averages, need to expand to match the x-axis scale for visualization
#
# We can plot `y` at the **midpoint of each group** for clarity.
#
# ---
#
# ### **Step 2: Plotting in Python**
#
# ```python id="q8n2kf"
# import numpy as np
# import matplotlib.pyplot as plt
#
# # summer_temp: original 100 random numbers
# # y: averages of 25 consecutive elements
#
# # X-axis for summer_temp
# x_temp = np.arange(1, 101)
#
# # X-axis for y (middle of each 25-element group)
# x_avg = np.array([12.5, 37.5, 62.5, 87.5])  # midpoints of 4 groups
#
# plt.figure(figsize=(10,5))
# plt.plot(x_temp, summer_temp, label="Original Temperatures", color='blue', alpha=0.6)
# plt.plot(x_avg, y, label="Average of 25 elements", color='red', marker='o', linewidth=2)
# plt.title("Summer Temperatures vs. Grouped Averages")
# plt.xlabel("Observation Number")
# plt.ylabel("Temperature")
# plt.legend()
# plt.grid(True)
# plt.show()
# ```
#
# ---
#
# ### **Step 3: What this plot shows**
#
# 1. **Blue line (raw data)**
#
#    * Shows the **original random variation** in summer temperatures.
#    * Peaks and valleys reflect randomness in the dataset.
#
# 2. **Red line (averages)**
#
#    * Smooths out the variation by showing the **mean of each 25-element group**.
#    * Gives a clearer idea of the **general trend or level** in the data.
#
# 3. **Comparison insight**
#
#    * You can see how averaging **reduces fluctuations** and highlights overall trends.
#    * Useful in data analysis when you want to focus on **patterns instead of random noise**.
#
# ---
#
#
#
# ## Conclusion
# Thus we have learned abou basics of ploting using *matplotlib*.
